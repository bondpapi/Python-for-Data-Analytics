# %% [markdown]
# # Specialization: Programming and EDA with Python
# ## Part 12: Graded Task

# %% [markdown]
# For this specialization, you learned the basics of Python and the packages designed to work with datasets -- Pandas and NumPy. You were also introduced to visualization packages, Matplotlib, Seaborn and Plotly. Now is time to combine these skills into an DA project. Your task is to analyze data with Python and create a notebook, where you can show your Python and analytical skills.

# %% [markdown]
# ## The Minimum Requirements for the Graded Task
# * Use Python data types: a list, a dictionary, an array, a dataframe.
# * Use Python functions to work with a dataset: join, filter, delete elements, etc.
# * Use Numpy and Pandas packages.
# * Use at least one package for visualization: Matplotlib, Seaborn, Plotly.
# * Use at least 3 different charts in your project.

# %% [markdown]
# A part of your project is to choose a problem to analyze and find a dataset. If you want to skip that part, you can use data provided by Turing College in BigQuery or any dataset from the learning material. To make your life even easier, you can replicate one of your previous projects you completed with  SQL, Spreadsheets or Data Studio. Please note that even though you can replicate your own project done with other tools, you may not copy and paste a previous notebook from the course with small modifications.

# %% [markdown]
# ## Evaluation Criteria
#
# * Minimum requirements are fulfilled: used different data types, used functions to handle datasets, used Numpy, Pandas and any of the visualizations package: Matplotlib, Seaborn, Plotly
# * Followed structured approach to data analysis
# * Quality of Python code

# %% [markdown]
# ## Sample Questions
#
# * We can ask you to modify any piece of your code to show that you understand what you have used. For example, we may ask you to choose different kwargs in your chart, to get summary statistics from your data, etc.
# * You should be able to explain how you decided which Python data type to use in a particular case.
# * We can ask you to explain your findings and conclusions.
